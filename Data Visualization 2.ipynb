# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Gun Deaths Data

# %%
pd.set_option('display.max_rows', 50)
gundata = pd.read_csv("/Users/wushuangyan/Projects/full_data.csv")
gundata
# Out:
#         Unnamed: 0  year  month    intent  police sex   age  \
# 0                1  2012      1   Suicide       0   M  34.0
# 1                2  2012      1   Suicide       0   F  21.0
# 2                3  2012      1   Suicide       0   M  60.0
# 3                4  2012      2   Suicide       0   M  64.0
# 4                5  2012      2   Suicide       0   M  31.0
# ...            ...   ...    ...       ...     ...  ..   ...
# 100793      100794  2014     12  Homicide       0   M  36.0
# 100794      100795  2014     12  Homicide       0   M  19.0
# 100795      100796  2014     12  Homicide       0   M  20.0
# 100796      100797  2014     12  Homicide       0   M  22.0
# 100797      100798  2014     10  Homicide       0   M  43.0
#
#                           race  hispanic              place     education
# 0       Asian/Pacific Islander       100               Home           BA+
# 1                        White       100             Street  Some college
# ...

# %%
print ("Races:", gundata.race.unique())
print ("Intentions:", gundata.intent.unique())
# Out:
# Races: ['Asian/Pacific Islander' 'White' 'Native American/Native Alaskan' 'Black'
#  'Hispanic']
# Intentions: ['Suicide' 'Undetermined' 'Accidental' 'Homicide' nan]

# %% [markdown]
# ## Data Plots

# %% [markdown]
# ### 1(a). Intention Distributions in Difference Genders and Races

# %%
plt.figure(figsize = (5,5))
plt.subplot(211)
gundata_af = gundata[(gundata.race == "Asian/Pacific Islander") & (gundata.sex == "F")]
gundata_afc = gundata_af.intent.value_counts()
intentn = ['Homicide','Suicide','Accidental','Undetermined']
gundata_afc = gundata_afc[intentn]  

xpos = np.arange(len(gundata_afc))
plt.bar(x = xpos, height = gundata_afc) 
plt.xlabel("Intent")
plt.title("Intent for Female Asian/Pacific Islander")
plt.xticks(xpos,intentn)

plt.subplot(212)
gundata_am = gundata[(gundata.race == racen[0]) & (gundata.sex == "M")]
gundata_amgundata_amc = gundata_am.intent.value_counts()
intentn = ['Homicide','Suicide','Accidental','Undetermined']
gundata_amc = gundata_amc[intentn]  

xpos = np.arange(len(gundata_amc))
plt.bar(x = xpos,height = gundata_amc) 
plt.xlabel("Intent")
plt.title("Intent for Male Asian/Pacific Islander")
plt.xticks(xpos,intentn)
plt.tight_layout()

# %%
plt.figure(figsize = (5,5))
plt.subplot(211)
gundata_wf = gundata[(gundata.race == racen[1]) & (gundata.sex == "F")]
gundata_wfc = gundata_wf.intent.value_counts()
intentn = ['Homicide','Suicide','Accidental','Undetermined']
gundata_wfc = gundata_wfc[intentn]  

xpos = np.arange(len(gundata_wfc))
plt.bar(x = xpos,height = gundata_wfc) 
plt.xlabel("Intent")
plt.title("Intent for Female White")
plt.xticks(xpos,intentn)

plt.subplot(212)
gundata_wm = gundata[(gundata.race == racen[1]) & (gundata.sex == "M")]
gundata_wmc = gundata_wm.intent.value_counts()
intentn = ['Homicide','Suicide','Accidental','Undetermined']
gundata_wmc = gundata_wmc[intentn]  

xpos = np.arange(len(gundata_wmc))
plt.bar(x = xpos,height = gundata_wmc) 
plt.xlabel("Intent")
plt.title("Intent for Male White")
plt.xticks(xpos,intentn)
plt.tight_layout()

# %%
plt.figure(figsize = (5,5))
plt.subplot(211)
gundata_tf = gundata[(gundata.race == racen[2]) & (gundata.sex == "F")]
gundata_tfc = gundata_tf.intent.value_counts()
intentn = ['Homicide','Suicide','Accidental','Undetermined']
gundata_tfc = gundata_tfc[intentn]  

xpos = np.arange(len(gundata_tfc))
plt.bar(x = xpos, height = gundata_tfc) 
plt.xlabel("Intent")
plt.title("Intent for Female Native American/Native Alaskan")
plt.xticks(xpos,intentn)

plt.subplot(212)
gundata_tm = gundata[(gundata.race == racen[2]) & (gundata.sex == "M")]
gundata_tmc = gundata_tm.intent.value_counts()
intentn = ['Homicide','Suicide','Accidental','Undetermined']
gundata_tmc = gundata_tmc[intentn]  

xpos = np.arange(len(gundata_tmc))
plt.bar(x = xpos, height = gundata_tmc) 
plt.xlabel("Intent")
plt.title("Intent for Male Native American/Native Alaskan")
plt.xticks(xpos,intentn)
plt.tight_layout()

# %%
plt.figure(figsize = (5,5))
plt.subplot(211)
gundata_bf = gundata[(gundata.race == racen[3]) & (gundata.sex == "F")]
gundata_bfc = gundata_bf.intent.value_counts()
intentn = ['Homicide','Suicide','Accidental','Undetermined']
gundata_bfc = gundata_bfc[intentn]  

xpos = np.arange(len(gundata_bfc))
plt.bar(x = xpos,height = gundata_bfc) 
plt.xlabel("Intent")
plt.title("Intent for Female Black")
plt.xticks(xpos,intentn)

plt.subplot(212)
gundata_bm = gundata[(gundata.race == racen[3]) & (gundata.sex == "M")]
gundata_bmc = gundata_bm.intent.value_counts()
intentn = ['Homicide','Suicide','Accidental','Undetermined']
gundata_bmc = gundata_bmc[intentn]  

xpos = np.arange(len(gundata_bmc))
plt.bar(x = xpos,height = gundata_bmc) 
plt.xlabel("Intent")
plt.title("Intent for Male Black")
plt.xticks(xpos, intentn)
plt.tight_layout()

# %%
plt.figure(figsize = (5,5))
plt.subplot(211)
gundata_hf = gundata[(gundata.race == racen[4]) & (gundata.sex == "F")]
gundata_hfc = gundata_hf.intent.value_counts()
intentn = ['Homicide','Suicide','Accidental','Undetermined']
gundata_hfc = gundata_hfc[intentn]  

xpos = np.arange(len(gundata_hfc))
plt.bar(x = xpos,height = gundata_hfc) 
plt.xlabel("Intent")
plt.title("Intent for Female Hispanic")
plt.xticks(xpos,intentn)

plt.subplot(212)
gundata_hm = gundata[(gundata.race == racen[4]) & (gundata.sex == "M")]
gundata_hmc = gundata_hm.intent.value_counts()
intentn = ['Homicide','Suicide','Accidental','Undetermined']
gundata_hmc = gundata_hmc[intentn]  

xpos = np.arange(len(gundata_hmc))
plt.bar(x = xpos,height = gundata_hmc) 
plt.xlabel("Intent")
plt.title("Intent for Male Hispanic")
plt.xticks(xpos, intentn)
plt.tight_layout()

# %% [markdown]
# ### 1(b). Age Distributions in Different Genders and Races

# %%
gundata_asf = gundata[(gundata.race == racen[0]) & (gundata.sex == "F")]
gundata_asm = gundata[(gundata.race == racen[0]) & (gundata.sex == "M")]
gundata_whf = gundata[(gundata.race == racen[1]) & (gundata.sex == "F")]
gundata_whm = gundata[(gundata.race == racen[1]) & (gundata.sex == "M")]
gundata_blf = gundata[(gundata.race == racen[3]) & (gundata.sex == "F")]
gundata_blm = gundata[(gundata.race == racen[3]) & (gundata.sex == "M")]

plt.figure(figsize = (8,8))
plt.subplot(311)
plt.hist(gundata_asm.age,bins = 50, color = "blue",label = "Male",alpha = 1)
plt.hist(gundata_asf.age,bins = 50, color = "yellow",label = "Female",alpha = 1)
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution - Asian/Pacific Islander")
plt.legend()

plt.subplot(312)
plt.hist(gundata_whm.age,bins = 50, color = "blue",label = "Male",alpha = 1)
plt.hist(gundata_whf.age,bins = 50, color = "yellow",label = "Female",alpha = 1)
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution - White")
plt.legend()

plt.subplot(313)
plt.hist(gundata_blm.age,bins = 50, color = "blue",label = "Male",alpha = 1)
plt.hist(gundata_blf.age,bins = 50, color = "yellow",label = "Female",alpha = 1)
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution - Black")
plt.legend()
plt.tight_layout()

# %% [markdown]
# ## Load Student Informatin (2015_16) Data

# %%
score = pd.read_csv("/Users/wushuangyan/Projects/MERGED2015_16_PP.csv",
                  na_values = [" ","NA","NULL","PrivacySuppressed"],
                    dtype = {'ZIP': 'str', 'T4APPROVALDATE': 'str','ALIAS':'str','NPCURL':'str'})

# %% [markdown]
# ## Data Plots

# %% [markdown]
# ### 2(a). Distributions of Median Debt in Varying Types of Schools

# %%
plt.figure(figsize = (7,7))
plt.subplot(311)
plt.hist(score.GRAD_DEBT_MDN[score.CONTROL == 1], bins = 30, color = "blue", label = "Male", alpha = 1)
plt.xlabel("Median debt (\$)")
plt.ylabel("Count")
plt.title("Median debt in public shcools")

plt.subplot(312)
plt.hist(score.GRAD_DEBT_MDN[score.CONTROL == 2], bins = 30, color = "blue", label = "Male", alpha = 1)
plt.xlabel("Median debt (\$)")
plt.ylabel("Count")
plt.title("Median debt in private not-for-profit shcools")

plt.subplot(313)
plt.hist(score.GRAD_DEBT_MDN[score.CONTROL == 3], bins = 30, color = "blue", label = "Male", alpha = 1)
plt.xlabel("Median debt (\$)")
plt.ylabel("Count")
plt.title("Median debt in private for-profit shcools")
plt.tight_layout()

# %% [markdown]
# ### 2(b). Distributions of Median Debt in Varying Types and Levels of Schools

# %%
#3(b)
plt.figure(figsize = (8,8))
plt.subplot(311)
plt.hist(score.GRAD_DEBT_MDN[score.CONTROL == 1][score.ICLEVEL == 1], bins = 30, color = "yellow", label = "4-year",alpha = 0.6)
plt.hist(score.GRAD_DEBT_MDN[score.CONTROL == 1][score.ICLEVEL == 2], bins = 30, color = "blue", label = "2-year",alpha = 0.6)
plt.hist(score.GRAD_DEBT_MDN[score.CONTROL == 1][score.ICLEVEL == 3], bins = 30, color = "red", label = "less than 2-year",alpha = 0.6)
plt.xlabel("Median debt (\$)")
plt.ylabel("Count")
plt.legend()
plt.title("Median debt in public shcools")


plt.subplot(312)
plt.hist(score.GRAD_DEBT_MDN[score.CONTROL == 2][score.ICLEVEL == 1], bins = 30, color = "yellow", label = "4-year",alpha = 0.6)
plt.hist(score.GRAD_DEBT_MDN[score.CONTROL == 2][score.ICLEVEL == 2], bins = 30, color = "blue", label = "2-year",alpha = 0.6)
plt.hist(score.GRAD_DEBT_MDN[score.CONTROL == 2][score.ICLEVEL == 3], bins = 30, color = "red", label = "less than 2-year",alpha = 0.6)
plt.xlabel("Median debt (\$)")
plt.ylabel("Count")
plt.legend()
plt.title("Median debt in private not-for-profit shcools")

plt.subplot(313) 
plt.hist(score.GRAD_DEBT_MDN[score.CONTROL == 3][score.ICLEVEL == 1],bins = 30, color = "yellow",label = "4-year",alpha = 0.6)
plt.hist(score.GRAD_DEBT_MDN[score.CONTROL == 3][score.ICLEVEL == 2],bins = 30, color = "blue",label = "2-year",alpha = 0.6)
plt.hist(score.GRAD_DEBT_MDN[score.CONTROL == 3][score.ICLEVEL == 3],bins = 30, color = "red",label = "less than 2-year",alpha = 0.6)
plt.xlabel("Median debt (\$)")
plt.ylabel("Count")
plt.title("Median debt in private for-profit shcools")
plt.legend()
plt.tight_layout()

# %% [markdown]
# ### 2(c). Distributions of Completion Rate in Varying Types of Schools

# %%
plt.figure(figsize = (7,7))
plt.subplot(311)
plt.hist(score.C200_4[score.CONTROL == 1],bins = 30, color = "blue",label = "4-year",alpha = 1)
plt.xlabel("Completion rate")
plt.ylabel("Count")
plt.title("Completion rate in public shcools")


plt.subplot(312)
plt.hist(score.C200_4[score.CONTROL == 2],bins = 30, color = "blue",label = "2-year",alpha = 1)
plt.xlabel("Completion rate")
plt.ylabel("Count")
plt.title("Completion rate in private not-for-profit shcools")

plt.subplot(313)
plt.hist(score.C200_4[score.CONTROL == 3],bins = 30, color = "blue",label = "less than 2 year",alpha = 1)
plt.xlabel("Completion rate")
plt.ylabel("Count")
plt.title("Completion rate in private for-profit shcools")
plt.tight_layout()

# %% [markdown]
# ### 2(d). Distributions of Median Debt in Varying Types and Levels of Schools

# %%
plt.figure(figsize = (8,8))
plt.subplot(311)
plt.hist(score.C200_4[score.CONTROL == 1][score.ICLEVEL == 1], bins = 30, color="yellow", label = "4-year", alpha = 0.6)
plt.hist(score.C200_L4[score.CONTROL == 1][score.ICLEVEL == 2], bins = 30, color="blue", label = "2-year", alpha = 0.6)
plt.hist(score.C200_L4[score.CONTROL == 1][score.ICLEVEL == 3], bins = 30, color="red", label = "less than 2 years", alpha = 0.6)
plt.xlabel("Completion rate")
plt.ylabel("Count")
plt.title("Completion rate in public shcools")
plt.legend()

plt.subplot(312)
plt.hist(score.C200_4[score.CONTROL == 2][score.ICLEVEL == 1],bins = 30, color = "yellow", label = "4-year", alpha = 0.6)
plt.hist(score.C200_L4[score.CONTROL == 2][score.ICLEVEL == 2],bins = 30, color = "blue", label = "2-year", alpha = 0.6)
plt.hist(score.C200_L4[score.CONTROL == 2][score.ICLEVEL == 3],bins = 30, color = "red", label = "less than 2 years", alpha = 0.6)
plt.xlabel("Completion rate")
plt.ylabel("Count")
plt.title("Completion rate in private not-for-profit shcools")
plt.legend()

plt.subplot(313)
plt.hist(score.C200_4[score.CONTROL == 3][score.ICLEVEL == 1], bins = 30, color = "yellow", label = "4-year", alpha = 0.6)
plt.hist(score.C200_L4[score.CONTROL == 3][score.ICLEVEL == 2], bins = 30, color = "blue", label = "2-year", alpha = 0.6)
plt.hist(score.C200_L4[score.CONTROL == 3][score.ICLEVEL == 3], bins = 30, color = "red", label = "less than 2 years", alpha = 0.6)
plt.xlabel("Completion rate")
plt.ylabel("Count")
plt.title("Completion rate in private for-profit shcools")
plt.legend()
plt.tight_layout()
